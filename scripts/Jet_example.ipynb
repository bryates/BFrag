# %%
import coffea
import coffea.processor as processor
import hist

import awkward as ak
import numpy as np
import matplotlib.pyplot as plt

# %%
fileset = {'tHq': ['root://xcache//store/mc/RunIISummer16NanoAODv5/THQ_Hincl_13TeV-madgraph-pythia8_TuneCUETP8M1/NANOAODSIM/PUMoriond17_Nano1June2019_102X_mcRun2_asymptotic_v7-v1/100000/38E83594-51BD-7D46-B96D-620DD60078A7.root',
                    'root://xcache//store/mc/RunIISummer16NanoAODv5/THQ_Hincl_13TeV-madgraph-pythia8_TuneCUETP8M1/NANOAODSIM/PUMoriond17_Nano1June2019_102X_mcRun2_asymptotic_v7-v1/100000/3A3BA22C-AA71-2544-810A-6DF4C6BA96FC.root',
                    'root://xcache//store/mc/RunIISummer16NanoAODv5/THQ_Hincl_13TeV-madgraph-pythia8_TuneCUETP8M1/NANOAODSIM/PUMoriond17_Nano1June2019_102X_mcRun2_asymptotic_v7-v1/100000/3AFB1F42-BC6D-D44E-86FD-DB93C83F88FF.root',
                    'root://xcache//store/mc/RunIISummer16NanoAODv5/THQ_Hincl_13TeV-madgraph-pythia8_TuneCUETP8M1/NANOAODSIM/PUMoriond17_Nano1June2019_102X_mcRun2_asymptotic_v7-v1/100000/A37B4B7A-FB5B-484D-8577-40B860D77D23.root',
                    'root://xcache//store/mc/RunIISummer16NanoAODv5/THQ_Hincl_13TeV-madgraph-pythia8_TuneCUETP8M1/NANOAODSIM/PUMoriond17_Nano1June2019_102X_mcRun2_asymptotic_v7-v1/100000/E3C7548E-EE40-BA45-9130-17DF56FBE537.root',
                    'root://xcache//store/mc/RunIISummer16NanoAODv5/THQ_Hincl_13TeV-madgraph-pythia8_TuneCUETP8M1/NANOAODSIM/PUMoriond17_Nano1June2019_102X_mcRun2_asymptotic_v7-v1/100000/F9EFC559-09E9-BB48-8150-9AA8B7F02C1C.root'],
            'tHW': ['root://xcache//store/mc/RunIISummer16NanoAODv5/THW_Hincl_13TeV-madgraph-pythia8_TuneCUETP8M1/NANOAODSIM/PUMoriond17_Nano1June2019_102X_mcRun2_asymptotic_v7-v1/70000/2806293E-D1DD-4A49-A274-0CC3BA57BBDF.root',
                    'root://xcache//store/mc/RunIISummer16NanoAODv5/THW_Hincl_13TeV-madgraph-pythia8_TuneCUETP8M1/NANOAODSIM/PUMoriond17_Nano1June2019_102X_mcRun2_asymptotic_v7-v1/70000/2F19962E-1DFB-A14A-91C2-30B69D5651D3.root',
                    'root://xcache//store/mc/RunIISummer16NanoAODv5/THW_Hincl_13TeV-madgraph-pythia8_TuneCUETP8M1/NANOAODSIM/PUMoriond17_Nano1June2019_102X_mcRun2_asymptotic_v7-v1/70000/D9744111-ED04-3F47-A52A-C18424F01609.root']}

# %%
fileset = {'ttbar': ['root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_101.root']}

# %%
fileset = {'ttbar': ['root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_1-1.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_1-10.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_1-11.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_1-12.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_1-13.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_1-14.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_1-15.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_1-16.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_1-17.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_1-18.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_1-19.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_1-2.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_1-20.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_1-21.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_1-22.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_1-23.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_1-24.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_1-25.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_1-26.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_1-27.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_1-28.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_1-29.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_1-3.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_1-30.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_1-31.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_1-32.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_1-33.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_1-34.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_1-35.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_1-36.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_1-37.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_1-38.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_1-39.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_1-4.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_1-40.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_1-41.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_1-42.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_1-43.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_1-44.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_1-45.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_1-46.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_1-47.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_1-48.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_1
root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_421.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_422.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_423.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_424.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_425.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_426.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_427.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_428.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_429.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_43.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_430.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_431.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_432.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_433.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_434.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_435.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_436.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_437.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_438.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_439.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_44.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_440.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_441.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_442.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_443.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_444.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_446.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_447.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_448.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_449.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_45.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_450.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_451.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_452.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_453.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_454.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_455.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_456.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_457.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_458.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_459.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_46.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_460.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_461.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_463.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_464.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_465.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_466.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_467.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_468.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_469.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_47.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_470.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_471.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_472.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_473.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_474.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_475.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_476.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_477.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_478.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_479.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_480.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_481.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_482.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_483.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_484.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_485.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_486.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_487.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_488.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_489.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_49.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_490.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_491.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_492.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_493.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_494.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_495.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_496.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_497.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_498.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_499.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_5.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_50.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_500.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_501.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_502.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_503.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_504.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_505.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_506.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_507.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_508.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_509.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_51.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_510.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_511.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_512.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_513.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_514.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_515.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_516.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_517.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_518.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_519.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_52.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_520.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_521.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_522.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_523.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_524.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_525.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_526.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_527.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_528.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_529.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_53.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_530.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_531.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_532.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_533.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_534.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_535.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_536.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_537.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_538.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_539.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_54.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_540.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_541.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_542.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_543.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_544.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_545.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_546.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_547.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_548.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_55.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_550.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_551.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_552.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_553.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_554.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_555.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_556.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_557.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_558.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_559.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_56.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_560.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_561.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_562.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_563.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_564.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_565.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_566.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_567.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_568.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_569.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_57.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_570.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_58.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_59.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_6.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_60.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_61.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_62.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_63.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_64.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_65.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_66.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_67.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_68.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_69.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_7.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_70.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_71.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_72.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_73.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_74.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_75.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_76.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_77.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_78.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_79.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_8.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_80.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_81.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_82.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_83.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_84.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_85.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_86.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_87.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_88.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_89.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_9.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_90.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_91.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_92.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_93.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_94.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_95.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_96.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_97.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_98.root',
                     'root://xcache//store/group/phys_top/byates/PFNano/TTToSemiLeptonic_TuneCP5_13TeV-powheg-pythia8/RunIISummer20UL16MiniAODv2-106X_mcRun2_asymptotic_v17-v1_PFtestNano/230405_134841/0000/nano_mc2017_ULv2_99.root']}

# %%
from dask.distributed import Client

client = Client("tls://localhost:8786")
# Out:
# /opt/conda/lib/python3.8/site-packages/distributed/client.py:1288: VersionMismatchWarning: Mismatched versions found
#
# +---------+----------------+----------------+----------------+
# | Package | client         | scheduler      | workers        |
# +---------+----------------+----------------+----------------+
# | python  | 3.8.16.final.0 | 3.8.16.final.0 | 3.8.15.final.0 |
# +---------+----------------+----------------+----------------+
#   warnings.warn(version_module.VersionMismatchWarning(msg[0]["warning"]))

# %%
def is_ttbar(jets, bjets, leptons):
        jets_pt = ak.fill_none(ak.pad_none(jets.pt, 1), 0)
        leps_pt  = ak.fill_none(ak.pad_none(leptons.pt, 1), 0)
        
        jets_eta = ak.fill_none(ak.pad_none(jets.eta, 1), 0)
        leps_eta  = ak.fill_none(ak.pad_none(leptons.eta, 1), 0)
        
        nJets = ak.num(jets)
        nBJets = ak.num(bjets)
        nLep = ak.num(leptons)
        jpt30 = jets_pt[:,0] > 30
        lpt25 = (leps_pt[:,0] > 25)
        jeta24 = abs(jets_eta) < 2.4
        leta24 = abs(leps_eta) < 2.4
        #is_ttbar = (ak.num(jets)>4)&(ak.num(bjets_tight)>1)&((ak.num(ele)>1)|(ak.num(mu)>1))# & (pad_jets[:,0].pt>30)# & ((pad_ele[:,0].pt>25) | (pad_mu[:,0].pt>25))#&(ht>180)
        return (nJets >= 1) & (nBJets >=1) & (nLep >= 1) & jpt30 & lpt25# & jeta24 & leta24

# %%
class Processor(processor.ProcessorABC):
    def __init__(self):
        self.mass_bins = np.linspace(1.7, 2.0, 30)
        self.xb_bins = np.linspace(0, 1, 11)

        dataset_axis = hist.axis.StrCategory(name="dataset", label="", categories=[], growth=True)
        # Split data into 50 bins, ranging from 0 to 100.
        jpt_axis = hist.axis.Regular(name="j0pt", label="Leading jet $p_{\mathrm{T}}$ [GeV]", bins=50, start=0, stop=300)
        bpt_axis = hist.axis.Regular(name="b0pt", label="Leading b jet $p_{\mathrm{T}}$ [GeV]", bins=50, start=0, stop=300)
        lpt_axis = hist.axis.Regular(name="l0pt", label="Leading lepotn $p_{\mathrm{T}}$ [GeV]", bins=50, start=0, stop=100)
        D0pt_axis= hist.axis.Regular(name="D0pt", label="Leading D0 $p_{\mathrm{T}}$ [GeV]", bins=50, start=0, stop=100)
        D0pipt_axis= hist.axis.Regular(name="D0pipt", label="Leading D0 pi $p_{\mathrm{T}}$ [GeV]", bins=50, start=0, stop=100)
        D0kpt_axis= hist.axis.Regular(name="D0kpt", label="Leading D0 k $p_{\mathrm{T}}$ [GeV]", bins=50, start=0, stop=100)
        xb_axis  = hist.axis.Regular(name="xb",   label="$x_{\mathrm{b}}$", bins=10, start=0, stop=1)
        xb_ch_axis  = hist.axis.Regular(name="xb_ch",   label="$x_{\mathrm{b}} \Sigma p_{\mathrm{T}}^{\mathrm{charged}}$", bins=10, start=0, stop=1)
        HT_axis  = hist.axis.Regular(name="HT",   label="$H_{\mathrm{T}}$", bins=50, start=0, stop=1000)
        pdgid_axis= hist.axis.Regular(name="pdgid",   label="D0 id's", bins=10, start=0, stop=250)
        d0_axis  = hist.axis.Regular(name='d0',   label="$d_0$", bins=10, start=0, stop=100)
        njets_axis = hist.axis.Regular(name='njets', label='$N_{\mathrm{jets}}$', bins=10, start=0, stop=10)
        nbjets_axis = hist.axis.Regular(name='nbjets', label='$N_{\mathrm{b-jets}}$', bins=10, start=0, stop=10)
        nleps_axis = hist.axis.Regular(name='nleps', label='$N_{\mathrm{leps}}$', bins=10, start=0, stop=10)
        mass_axis = hist.axis.Regular(name='d0_mass', label='D0 mass [GeV]', bins=30, start=self.mass_bins[0], stop=self.mass_bins[-1])
        mass_tag_axis = hist.axis.Regular(name='d0_mu_mass', label='D0 mu-tag mass [GeV]', bins=30, start=self.mass_bins[0], stop=self.mass_bins[-1])
        mass_axes = [hist.axis.Regular(name=f'd0_{int(xb_bin*10)}', label='D0 mass [GeV] (' + str(round(self.xb_bins[ibin], 2)) + ' < $x_{\mathrm{b}}$ < ' + str(round(self.xb_bins[ibin+1], 2)) + ')', bins=30, start=1.7, stop=2.0) for ibin,xb_bin in enumerate(self.xb_bins[:-1])]
        self.output = processor.dict_accumulator({
            'j0pt': hist.Hist(dataset_axis, jpt_axis),
            'b0pt': hist.Hist(dataset_axis, bpt_axis),
            'l0pt': hist.Hist(dataset_axis, lpt_axis),
            'D0pt': hist.Hist(dataset_axis, D0pt_axis),
            'D0pipt': hist.Hist(dataset_axis, D0pipt_axis),
            'D0kpt': hist.Hist(dataset_axis, D0kpt_axis),
            'xb'  : hist.Hist(dataset_axis, xb_axis),
            'xb_ch'  : hist.Hist(dataset_axis, xb_ch_axis),
            'HT'  : hist.Hist(dataset_axis, HT_axis),
            'pdgid'  : hist.Hist(dataset_axis, pdgid_axis),
            'd0'  : hist.Hist(dataset_axis, d0_axis),
            'njets' : hist.Hist(dataset_axis, njets_axis),
            'nbjets' : hist.Hist(dataset_axis, nbjets_axis),
            'nleps' : hist.Hist(dataset_axis, nleps_axis),
            'd0_mass': hist.Hist(dataset_axis, mass_axis),
            'd0_mu_mass': hist.Hist(dataset_axis, mass_tag_axis),
            # FIXME make these dynamically
            'd0_0' : hist.Hist(dataset_axis, mass_axes[0]),
            'd0_1' : hist.Hist(dataset_axis, mass_axes[1]),
            'd0_2' : hist.Hist(dataset_axis, mass_axes[2]),
            'd0_3' : hist.Hist(dataset_axis, mass_axes[3]),
            'd0_4' : hist.Hist(dataset_axis, mass_axes[4]),
            'd0_5' : hist.Hist(dataset_axis, mass_axes[5]),
            'd0_6' : hist.Hist(dataset_axis, mass_axes[6]),
            'd0_7' : hist.Hist(dataset_axis, mass_axes[7]),
            'd0_8' : hist.Hist(dataset_axis, mass_axes[8]),
            'd0_9' : hist.Hist(dataset_axis, mass_axes[9]),
            #'d0_10' : hist.Hist(dataset_axis, mass_axes[10]),
        })
    
    def process(self, events):
        dataset = events.metadata["dataset"]
        #events = events[events.is_ttbar]
        jets = events.Jet
        ele  = events.Electron
        mu   = events.Muon
        leptons = ak.with_name(ak.concatenate([ele, mu], axis=1), 'PtEtaPhiMCandidate')
        leptons = leptons[ak.argsort(leptons.pt, axis=1)][::-1]
        
        '''
        jets_pt = ak.fill_none(ak.pad_none(jets.pt, 1), 0)
        ele_pt  = ak.fill_none(ak.pad_none(ele.pt, 1), 0)
        mu_pt   = ak.fill_none(ak.pad_none(mu.pt, 1), 0)
        
        jets_eta = ak.fill_none(ak.pad_none(jets.eta, 1), 0)
        ele_eta  = ak.fill_none(ak.pad_none(ele.eta, 1), 0)
        mu_eta   = ak.fill_none(ak.pad_none(mu.eta, 1), 0)
        '''
        
        loose = 0.1355
        medium = 0.4506
        tight = 0.7738
        is_bjets_tight = jets['btagDeepFlavB'] > tight
        bjets_tight = ak.pad_none(jets[is_bjets_tight], 1)
        events['is_ttbar'] = is_ttbar(jets, bjets_tight, leptons)
        ht = ak.sum(jets.pt, axis=-1)
        j0pt = ak.fill_none(ak.pad_none(jets.pt, 1), 0)[:,0]
        l0pt = ak.fill_none(ak.pad_none(ak.pad_none(leptons.pt, 1), -1)[:,0], -1)
        b0pt = ak.fill_none(bjets_tight.pt[:,0], -1)
        
        # PF candidates from b-jets
        pf = ak.with_name(events.PFCands._apply_global_index(bjets_tight.pFCandsIdxG), 'PtEtaPhiMCandidate')
        mu_tag = ak.any(np.abs(pf.pdgId) == 13, axis=-1)
        #pf = pf[mu_tag]

        d0_cand = ak.cartesian({'pi':pf, 'k':pf})
        pi = ak.flatten(d0_cand.pi)
        k = ak.flatten(d0_cand.k)
        pi = d0_cand.pi[d0_cand.pi.pt>1]
        k = d0_cand.k[d0_cand.k.pt>1]
        k['mass'] = 0.4937
        #pi = pi[pi.d0/pi.d0Err>10]
        #k = k[k.d0/k.d0Err>10]
        
        d0 = ak.flatten(pi, -1) + ak.flatten(k, -1)
        d0['d0'] = np.sqrt(np.square(ak.flatten(pi, -1).d0) + np.square(ak.flatten(k, -1).d0))
        # OS charged hadrons only
        pi_id = ak.fill_none(ak.pad_none(ak.flatten(pi.pdgId, -1), 1), -1)
        k_id = ak.fill_none(ak.pad_none(ak.flatten(k.pdgId, -1), 1), -1)
        pi_d0 = ak.fill_none(ak.pad_none(ak.flatten(pi.d0, -1), 1), -1)
        k_d0  = ak.fill_none(ak.pad_none(ak.flatten(k.d0, -1), 1), -1)
        pi_d0Err = ak.fill_none(ak.pad_none(ak.flatten(pi.d0Err, -1), 1), -1)
        k_d0Err  = ak.fill_none(ak.pad_none(ak.flatten(k.d0Err, -1), 1), -1)
        pi_dz = ak.fill_none(ak.pad_none(ak.flatten(pi.d0, -1), 1), -1)
        k_dz  = ak.fill_none(ak.pad_none(ak.flatten(k.d0, -1), 1), -1)
        pi_dzErr = ak.fill_none(ak.pad_none(ak.flatten(pi.d0Err, -1), 1), -1)
        k_dzErr  = ak.fill_none(ak.pad_none(ak.flatten(k.d0Err, -1), 1), -1)
        d0_d0 = np.sqrt(np.square(pi_d0) + np.square(k_d0))
        d0_d0Err = np.sqrt(np.square(pi_d0Err) + np.square(k_d0Err))
        d0_dz = np.sqrt(np.square(pi_dz) + np.square(k_dz))
        d0_dzErr = np.sqrt(np.square(pi_dzErr) + np.square(k_dzErr))
        d0_3dip = np.sqrt(np.square(d0_d0) + np.square(d0_dz))
        d0_3dipErr = np.sqrt(np.square(d0_d0Err) + np.square(d0_dzErr))
        pf_mask = (pi_id * k_id == -211*211) & (d0_3dip/d0_3dipErr > 10)#(pi_d0sig > 10) & (k_d0sig > 10)
        self.output['pdgid'].fill(dataset=dataset, pdgid=ak.flatten(np.sqrt(-1*pi_id[pf_mask] * k_id[pf_mask])))
        d0 = d0[pf_mask]
        #d0 = d0[(pi.d0/pi.d0Err>10)]
        d0_mask = (d0.mass>self.mass_bins[0])&(d0.mass<self.mass_bins[-1])#&pf_mask#&(pi.pdgId*k.pdgId == -211*211)
        d0_mass = ak.fill_none(ak.pad_none(d0.mass[d0_mask], 1), -1)
        d0_lead_mass = ak.fill_none(ak.pad_none(d0.mass[d0_mask], 1), -1)[:,0]
        d0_lead_pt = ak.fill_none(ak.pad_none(d0.pt[d0_mask], 1), -1)[:,0]
        d0_imp = ak.fill_none(ak.pad_none(d0.d0[d0_mask], 1), -1)[:,0]
        xb = d0_lead_pt / ak.flatten(ak.fill_none(bjets_tight.pt, -1)[:,0], axis=0)
        charged = pf.charge != 0
        jpt_ch = ak.sum(pf[charged].pt, axis=-1)
        xb_ch = d0_lead_pt / ak.flatten(ak.fill_none(jpt_ch, -1)[:,0], axis=0)
        
        d0_cand = ak.argcartesian({'pi': pf, 'k': pf}, axis=1)
        pi_idx = d0_cand.pi
        k_idx = d0_cand.k
        pi = pf[d0_cand[pi_idx != k_idx].pi]
        k = pf[d0_cand[pi_idx != k_idx].k]
        k['mass'] = 0.4937
        d0 = ak.flatten(pi, -1) + ak.flatten(k, -1)
        d0_mask = (d0.mass>self.mass_bins[0])&(d0.mass<self.mass_bins[-1])
        d0_lead_mass = ak.fill_none(ak.pad_none(d0.mass[d0_mask], 1), -1)[:,0]
        '''
        combos = ak.combinations(pf, 2, fields=["i", "j"])
        i, j = ak.unzip(ak.combinations(pf, 2, fields=["i", "j"]))
        m_kaon = 0.4397
        m_pion = 0.1396
        i_pion = ak.with_field(i, m_pion, "mass")
        j_pion = ak.with_field(j, m_pion, "mass")
        i_kaon = ak.with_field(i, m_kaon, "mass")
        j_kaon = ak.with_field(j, m_kaon, "mass")
        d0 = i_pion + i_kaon
        d0_mask = (d0.mass > 1.7) & (d0.mass < 2.0)
        d0_lead_mass = ak.pad_none(ak.flatten(d0, 1).mass, 1)[:,0]
        d0_lead_mass = ak.flatten(d0[events.is_ttbar], axis=1).mass[:,0]
        '''
        
        #binned_masses = [d0_lead_mass[events.is_ttbar & (xb > low) & (xb < high)] for low,high in zip(self.xb_bins[:-1], self.xb_bins[1:])]
        binned_masses = [d0_lead_mass[(xb > low) & (xb < high)] for low,high in zip(self.xb_bins[:-1], self.xb_bins[1:])]
        self.output['j0pt'].fill(dataset=dataset, j0pt=j0pt[events.is_ttbar])
        self.output['b0pt'].fill(dataset=dataset, b0pt=b0pt[events.is_ttbar])
        self.output['l0pt'].fill(dataset=dataset, l0pt=l0pt[events.is_ttbar])
        self.output['njets'].fill(dataset=dataset, njets=ak.num(jets[events.is_ttbar]))
        self.output['nbjets'].fill(dataset=dataset, nbjets=ak.num(bjets_tight[events.is_ttbar]))
        self.output['nleps'].fill(dataset=dataset, nleps=ak.num(leptons[events.is_ttbar]))
        self.output['HT'].fill(dataset=dataset, HT=ht)
        self.output['D0pt'].fill(dataset=dataset, D0pt=d0_lead_pt)
        self.output['xb'].fill(dataset=dataset, xb=xb[events.is_ttbar])
        self.output['xb_ch'].fill(dataset=dataset, xb_ch=xb_ch[events.is_ttbar])
        self.output['d0'].fill(dataset=dataset, d0=d0_imp)
        self.output['d0_mass'].fill(dataset=dataset, d0_mass=d0_lead_mass)#[events.is_ttbar])
        # mu_tag is at jet level, cartesian associates each PF in a jet with the jet-level flag
        d0_tag, is_tag = ak.unzip(ak.cartesian([d0_mass, mu_tag]))
        self.output['d0_mu_mass'].fill(dataset=dataset, d0_mu_mass=ak.fill_none(ak.flatten(d0_tag[is_tag]), 0))
        for ibin in range(len(self.xb_bins)-1):
            self.output[f'd0_{ibin}'].fill(**{'dataset': dataset, f'd0_{ibin}': binned_masses[ibin]})
        '''
        # FIXME make these dynamically
        self.output['d0_0'].fill(dataset=dataset, d0_0=binned_masses[0])
        self.output['d0_1'].fill(dataset=dataset, d0_1=binned_masses[1])
        self.output['d0_2'].fill(dataset=dataset, d0_2=binned_masses[2])
        self.output['d0_3'].fill(dataset=dataset, d0_3=binned_masses[3])
        self.output['d0_4'].fill(dataset=dataset, d0_4=binned_masses[4])
        self.output['d0_5'].fill(dataset=dataset, d0_5=binned_masses[5])
        self.output['d0_6'].fill(dataset=dataset, d0_6=binned_masses[6])
        self.output['d0_7'].fill(dataset=dataset, d0_7=binned_masses[7])
        self.output['d0_8'].fill(dataset=dataset, d0_8=binned_masses[8])
        #self.output['d0_9'].fill(dataset=dataset, d0_9=binned_masses[9])
        '''
        #self.output['D0pipt'].fill(dataset=dataset, D0pipt=d0pi_lead_pt)
        #self.output['D0kpt'].fill(dataset=dataset, D0kpt=d0pi_lead_pt)
        return self.output

    def postprocess(self, accumulator):
        return accumulator

# %%
output = processor.run_uproot_job(fileset=fileset, 
                       treename="Events",
                       processor_instance=Processor(),
                       executor=processor.dask_executor,
                       executor_args={'client': client, 'schema': processor.NanoAODSchema},
                       chunksize=50000)
# Out:
# [########################################] | 100% Completed |  4min 27.5s

# %%
output['d0_mass'].plot1d()
#output['d0_mu_mass'].plot1d()
# Out:
# [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7fb8709ff670>, errorbar=None, legend_artist=None)]

# %%
output['njets'].plot1d(label='njets')
output['nbjets'].plot1d(label='nbjets')
output['nleps'].plot1d(label='nleps')
plt.legend()

# %%
output['l0pt'].plot1d(label='l0 pt')
output['j0pt'].plot1d(label='j0 pt')
plt.legend()

# %%
output['HT'].plot1d(label='HT')
# Out:
# [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7fb872c9e430>, errorbar=None, legend_artist=None)]

# %%
#output['j0pt'].plot1d()
output['b0pt'].plot1d()
output['D0pt'].plot1d()
# Out:
# [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7fb872b7ab50>, errorbar=None, legend_artist=None)]

# %%
output['xb'].plot1d()
output['xb_ch'].plot1d()
# Out:
# [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7fb872b0ab20>, errorbar=None, legend_artist=None)]

# %%
output['HT'].plot1d()
# Out:
# [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7fb872a6f880>, errorbar=None, legend_artist=None)]

# %%
output['pdgid'].plot1d()
# Out:
# [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7fb872a18280>, errorbar=None, legend_artist=None)]

# %%
output['d0'].plot1d()
# Out:
# [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7fb872959610>, errorbar=None, legend_artist=None)]

# %%
output.keys()
# Out:
# dict_keys(['j0pt', 'b0pt', 'l0pt', 'D0pt', 'D0pipt', 'D0kpt', 'xb', 'xb_ch', 'HT', 'pdgid', 'd0', 'njets', 'nbjets', 'nleps', 'd0_mass', 'd0_mu_mass', 'd0_0', 'd0_1', 'd0_2', 'd0_3', 'd0_4', 'd0_5', 'd0_6', 'd0_7', 'd0_8', 'd0_9'])

# %%
import matplotlib.pyplot as plt

# %%
#output['d0_1'].plot1d(label='d0_1')
#output['d0_2'].plot1d(label='d0_2')
#output['d0_3'].plot1d(label='d0_3')
#output['d0_4'].plot1d(label='d0_4')
#output['d0_5'].plot1d(label='d0_5')
#output['d0_6'].plot1d(label='d0_6')
#output['d0_7'].plot1d(label='d0_7')
#output['d0_8'].plot1d(label='d0_8')
for key in output:
    if 'd0_' in key and len(output[key].view()) != 0 and 'd0_' in key and 'mass' not in key:
    #if 'd0_' in key and 'd0_9' not in key:
        output[key].plot1d(label=key)
plt.legend()

# %%
output['d0_mu_mass'].plot1d()
# Out:
# [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7fb872882a60>, errorbar=None, legend_artist=None)]

# %%
output['xb'][{'dataset': sum}][0:len(output['xb'].axes['xb'].edges)]
# Out:
# Hist(Regular(10, 0, 1, name='xb', label='$x_{\\mathrm{b}}$'), storage=Double()) # Sum: 8527.0 (1638758.0 with flow)
